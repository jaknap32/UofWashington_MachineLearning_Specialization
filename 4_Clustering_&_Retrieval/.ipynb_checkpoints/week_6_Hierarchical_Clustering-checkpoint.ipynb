# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.cluster import KMeans                # we'll be using scikit-learn's KMeans for this assignment
from sklearn.metrics import pairwise_distances
from sklearn.preprocessing import normalize

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
wiki = pd.read_csv(r"D:\dasci\github\datasets\coursera_ML_UW\4_Clustering_&_Retrieval\people_wiki.csv")

# %%
def load_sparse_csr(filename):
    loader = np.load(filename)
    data = loader['data']
    indices = loader['indices']
    indptr = loader['indptr']
    shape = loader['shape']
    
    return csr_matrix( (data, indices, indptr), shape)

# %%
word_count = load_sparse_csr(r"D:\dasci\github\datasets\coursera_ML_UW\4_Clustering_&_Retrieval\people_wiki_word_count.npz")

# %%
import json

with open(r"D:\dasci\github\datasets\coursera_ML_UW\4_Clustering_&_Retrieval\people_wiki_map_index_to_word.json") as jsn:
    map_index_to_word = json.load(jsn)

# %%
def unpack_dict(matrix, map_index_to_word):
    table = sorted(map_index_to_word, key=map_index_to_word.get)
    
    data = matrix.data
    indices = matrix.indices
    indptr = matrix.indptr
    
    num_doc = matrix.shape[0]

    return [{k:v for k,v in zip([table[word_id] for word_id in indices[indptr[i]:indptr[i+1]] ],
                                 data[indptr[i]:indptr[i+1]].tolist())} \
               for i in range(num_doc) ]

wiki['word_count'] = unpack_dict(word_count, map_index_to_word)

# %%
tf_idf = load_sparse_csr(r"D:\dasci\github\datasets\coursera_ML_UW\4_Clustering_&_Retrieval\people_wiki_tf_idf.npz")

# %%
tf_idf = normalize(tf_idf)

# %%
def bipartition(cluster, maxiter=400, num_runs=4, seed=None):
    '''cluster: should be a dictionary containing the following keys
                * dataframe: original dataframe
                * matrix:    same data, in matrix format
                * centroid:  centroid for this particular cluster'''
    
    data_matrix = cluster['matrix']
    dataframe   = cluster['dataframe']
    
    # Run k-means on the data matrix with k=2. We use scikit-learn here to simplify workflow.
    kmeans_model = KMeans(n_clusters=2, max_iter=maxiter, n_init=num_runs, random_state=seed, n_jobs=1)    
    kmeans_model.fit(data_matrix)
    centroids, cluster_assignment = kmeans_model.cluster_centers_, kmeans_model.labels_
    
    # Divide the data matrix into two parts using the cluster assignments.
    data_matrix_left_child, data_matrix_right_child = data_matrix[cluster_assignment==0], \
                                                      data_matrix[cluster_assignment==1]
    
    # Divide the dataframe into two parts, again using the cluster assignments.
    cluster_assignment_sa = np.array(cluster_assignment) # minor format conversion
    dataframe_left_child, dataframe_right_child     = dataframe[cluster_assignment_sa==0], \
                                                      dataframe[cluster_assignment_sa==1]
        
    
    # Package relevant variables for the child clusters
    cluster_left_child  = {'matrix': data_matrix_left_child,
                           'dataframe': dataframe_left_child,
                           'centroid': centroids[0]}
    cluster_right_child = {'matrix': data_matrix_right_child,
                           'dataframe': dataframe_right_child,
                           'centroid': centroids[1]}
    
    return (cluster_left_child, cluster_right_child)

# %%
wiki_data = {'matrix': tf_idf, 'dataframe': wiki} # no 'centroid' for the root cluster
left_child, right_child = bipartition(wiki_data, maxiter=100, num_runs=6, seed=1)

# %%
print (left_child)
print (right_child)
# Out:
# {'matrix': <11510x547979 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1885831 stored elements in Compressed Sparse Row format>, 'dataframe':                                                      URI  \
# 0            <http://dbpedia.org/resource/Digby_Morrell>
# 17     <http://dbpedia.org/resource/Paddy_Dunne_(Gael...
# 21           <http://dbpedia.org/resource/Ceiron_Thomas>
# 22            <http://dbpedia.org/resource/Adel_Sellimi>
# 25             <http://dbpedia.org/resource/Vic_Stasiuk>
# 28            <http://dbpedia.org/resource/Leon_Hapgood>
# 30               <http://dbpedia.org/resource/Dom_Flora>
# 33               <http://dbpedia.org/resource/Bob_Reece>
# 41     <http://dbpedia.org/resource/Bob_Adams_(Americ...
# 48              <http://dbpedia.org/resource/Marc_Logan>
# 49          <http://dbpedia.org/resource/Corey_Woolfolk>
# 63              <http://dbpedia.org/resource/Alan_Roper>
# 75      <http://dbpedia.org/resource/Vladimir_Yurchenko>
# 78           <http://dbpedia.org/resource/Doug_McIntosh>
# 92            <http://dbpedia.org/resource/Shaka_Hislop>
# 95            <http://dbpedia.org/resource/Steve_Castle>
# 99              <http://dbpedia.org/resource/Dean_Greig>
# 101    <http://dbpedia.org/resource/James_Stewart_(Am...
# 102       <http://dbpedia.org/resource/Fredrik_Jacobson>
# 105     <http://dbpedia.org/resource/Juan_Pablo_Montoya>
# 114            <http://dbpedia.org/resource/Al_Hairston>
# 116             <http://dbpedia.org/resource/Ron_Shuman>
# 118    <http://dbpedia.org/resource/Bill_Young_(Austr...
# 122    <http://dbpedia.org/resource/Se%C3%A1n_%C3%93g...
# 123        <http://dbpedia.org/resource/Mike_Trebilcock>
# 137          <http://dbpedia.org/resource/Daniel_Falzon>
# 145          <http://dbpedia.org/resource/Cameron_Sharp>
# 151              <http://dbpedia.org/resource/Gary_Fila>
# 152    <http://dbpedia.org/resource/Roger_James_(foot...
# 153      <http://dbpedia.org/resource/Aled_de_Malmanche>
# ...                                                  ...
# 58932  <http://dbpedia.org/resource/Kevin_Clark_(bask...
# 58933         <http://dbpedia.org/resource/Justin_Huish>
# 58940           <http://dbpedia.org/resource/Lamar_King>
# 58941        <http://dbpedia.org/resource/Tyler_Lockett>
# 58943    <http://dbpedia.org/resource/Bernadette_Benson>
# 58944        <http://dbpedia.org/resource/Blake_Russell>
# 58949           <http://dbpedia.org/resource/Marc_Sneyd>
# 58950           <http://dbpedia.org/resource/John_Arigo>
# 58954         <http://dbpedia.org/resource/Paul_Foytack>
# 58960     <http://dbpedia.org/resource/Sergey_Erzrumyan>
# 58962  <http://dbpedia.org/resource/David_Leslie_(rug...
# 58968            <http://dbpedia.org/resource/Kurt_Luby>
# 58969         <http://dbpedia.org/resource/Ray_Daviault>
# 58982  <http://dbpedia.org/resource/Jeff_Gray_(baseba...
# 58985  <http://dbpedia.org/resource/Craig_Davis_(Aust...
# 58987         <http://dbpedia.org/resource/Mike_Bruhert>
# 58988         <http://dbpedia.org/resource/Jack_Swagger>
# 58992             <http://dbpedia.org/resource/Jim_Eddy>
# 58993  <http://dbpedia.org/resource/Edgar_Renter%C3%ADa>
# 59003    <http://dbpedia.org/resource/Beth_Dunkenberger>
# 59007            <http://dbpedia.org/resource/Brad_Huse>
# 59010         <http://dbpedia.org/resource/Kaid_Mohamed>
# 59018  <http://dbpedia.org/resource/Jim_Casey_(footba...
# 59026  <http://dbpedia.org/resource/Richard_Thompson_...
# 59028         <http://dbpedia.org/resource/Eric_Naposki>
# 59051     <http://dbpedia.org/resource/Geoffrey_Kipsang>
# 59052         <http://dbpedia.org/resource/Dave_Nilsson>
# 59065  <http://dbpedia.org/resource/Dee_Brown_(basket...
# 59068  <http://dbpedia.org/resource/David_Cass_(footb...
# 59069          <http://dbpedia.org/resource/Keith_Elias>
#
#                                            name  \
# 0                                 Digby Morrell
# 17              Paddy Dunne (Gaelic footballer)
# 21                                Ceiron Thomas
# 22                                 Adel Sellimi
# 25                                  Vic Stasiuk
# 28                                 Leon Hapgood
# 30                                    Dom Flora
# 33                                    Bob Reece
# 41                Bob Adams (American football)
# 48                                   Marc Logan
# 49                               Corey Woolfolk
# 63                                   Alan Roper
# 75                           Vladimir Yurchenko
# 78                                Doug McIntosh
# 92                                 Shaka Hislop
# 95                                 Steve Castle
# 99                                   Dean Greig
# 101           James Stewart (American football)
# 102                            Fredrik Jacobson
# 105                          Juan Pablo Montoya
# 114                                 Al Hairston
# 116                                  Ron Shuman
# 118    Bill Young (Australian rules footballer)
# 122       Se%C3%A1n %C3%93g %C3%93 hAilp%C3%ADn
# 123                             Mike Trebilcock
# 137                               Daniel Falzon
# 145                               Cameron Sharp
# 151                                   Gary Fila
# 152                    Roger James (footballer)
# 153                           Aled de Malmanche
# ...                                         ...
# 58932                  Kevin Clark (basketball)
# 58933                              Justin Huish
# 58940                                Lamar King
# 58941                             Tyler Lockett
# 58943                         Bernadette Benson
# 58944                             Blake Russell
# 58949                                Marc Sneyd
# 58950                                John Arigo
# 58954                              Paul Foytack
# 58960                          Sergey Erzrumyan
# 58962                David Leslie (rugby union)
# 58968                                 Kurt Luby
# 58969                              Ray Daviault
# 58982           Jeff Gray (baseball, born 1963)
# 58985       Craig Davis (Australian footballer)
# 58987                              Mike Bruhert
# 58988                              Jack Swagger
# 58992                                  Jim Eddy
# 58993                       Edgar Renter%C3%ADa
# 59003                         Beth Dunkenberger
# 59007                                 Brad Huse
# 59010                              Kaid Mohamed
# 59018                    Jim Casey (footballer)
# 59026  Richard Thompson (footballer, born 1969)
# 59028                              Eric Naposki
# 59051                          Geoffrey Kipsang
# 59052                              Dave Nilsson
# 59065         Dee Brown (basketball, born 1968)
# 59068                   David Cass (footballer)
# 59069                               Keith Elias
#
#                                                     text  \
# 0      digby morrell born 10 october 1979 is a former...
# 17     paddy dunne was a gaelic football player from ...
# 21     ceiron thomas born 23 october 1983 is a welsh ...
# 22     adel sellimi arabic was born on 16 november 19...
# 25     victor john stasiuk born may 23 1929 is a reti...
# 28     leon duane hapgood born 7 august 1979is an eng...
# 30     dominick a dom flora born june 12 1935 is an a...
# 33     robert scott reece born january 5 1951 is an a...
# 41     robert bruce bob adams born august 15 1946 in ...
# 48     marc anthony logan born may 9 1965 is a former...
# 49     corey woolfolk born february 26 1983 in ann ar...
# 63     alan roper born may 1939 in tipton staffordshi...
# 75     uladzimir vasilyevich yurchanka belarusian rus...
# 78     doug mcinstosh is a retired american basketbal...
# 92     neil shaka hislop cm born 22 february 1969 is ...
# 95     steve castle born 17 may 1966 in barking is a ...
# 99     dean greig born 31 october 1968 is a former au...
# 101    james ottis stewart born december 27 1971 is a...
# 102    fredrik ulf yngve jacobson born 26 september 1...
# 105    juan pablo montoya roldn born september 20 197...
# 114    alan leroy al hairston born december 11 1945 i...
# 116    ron shuman born september 15 1952 is an americ...
# 118    william d bill young born 6 june 1931 is a for...
# 122    sen g hailpn born 22 may 1977 is a fijianirish...
# 123    michael mike trebilcock born 29 november 1944 ...
# 137    daniel lawson falzon born 16 march 1994 is a p...
# 145    robert cameron sharp born 3 june 1958 is a sco...
# 151    gary fila born 18 november 1981 is australian ...
# 152    roger james born 21 october 1975 is a former a...
# 153    aled peter de malmanche born 11 september 1984...
# ...                                                  ...
# 58932  kevin clark is an assistant mens basketball co...
# 58933  justin huish is an american double olympic cha...
# 58940  lamar king born august 10 1975 is a former ame...
# 58941  tyler lockett born september 28 1992 is an ame...
# 58943  bernadette benson is a canadian born athlete s...
# 58944  blake russell ne phillips born july 24 1975 is...
# 58949  marc sneyd is an english professional rugby le...
# 58950  john hartley ward arigo born december 10 1978 ...
# 58954  paul eugene foytack born november 16 1930 in s...
# 58960  sergey erzrumyan born on 22 november 1980 is a...
# 58962  david leslie born 14 april 1952 is a former sc...
# 58968  kurt luby born 6 march 1963 in bolton lancashi...
# 58969  raymond joseph robert daviault born may 27 193...
# 58982  jeffrey edward gray born april 10 1963 in rich...
# 58985  craig davis born 2 october 1954 in ross tasman...
# 58987  michael edwin bruhert born june 21 1951 is a f...
# 58988  donald jacob jake hager born march 24 1982 is ...
# 58992  jim eddy is a football coach who worked in the...
# 58993  edgar enrique rentera herazo spanish pronuncia...
# 59003  beth dunkenberger is in her second season with...
# 59007  brad huse born june 27 1966 is an american col...
# 59010  kaid yusef mohamed born 23 july 1984 is a wels...
# 59018  jim casey born august 2 1957 in glasgow is a r...
# 59026  richard john thompson born 11 april 1969 in ha...
# 59028  eric andrew naposki born december 20 1966 is a...
# 59051  geoffrey kipsang kamworor born 22 november 199...
# 59052  david wayne nilsson born 14 december 1969 is a...
# 59065  decovan kadell dee brown born november 29 1968...
# 59068  david william royce cass born 27 march 1962 in...
# 59069  keith hector elias born february 3 1972 in lac...
#
#                                               word_count
# 0      {'brisbaneafter': 1, 'edflhe': 1, 'aflfrom': 1...
# 17     {'1953called': 1, 'laoishe': 1, '1950swith': 1...
# 21     {'ceiron': 1, 'pointsthomas': 1, 'leaguehoweve...
# 22     {'jendouba': 1, 'breaka': 1, 'frenchmans': 1, ...
# 25     {'offensiverich': 1, 'coaching4': 1, 'bucyk': ...
# 28     {'bidefordhe': 1, '1979is': 1, 'schoolboyshapg...
# 30     {'wlbill': 1, '696for954': 1, 'floraflora': 1,...
# 33     {'appearancereece': 1, 'kgreece': 1, '672': 1,...
# 41     {'criminon': 1, 'scovil': 1, 'narconon': 1, 'p...
# 48     {'nflmarc': 1, 'd1a': 1, '1135': 1, '1391': 1,...
# 49     {'forwardwoolfolk': 1, 'woolfolk': 4, 'riverho...
# 63     {'tiptonhe': 1, '2008references': 1, 'diseaseh...
# 75     {'salihorskyurchenko': 1, 'shakhtyor': 1, 'per...
# 78     {'mcinstosh': 1, '1965mcintosh': 1, 'gameyears...
# 92     {'200203he': 1, 'shaka': 1, 'quinnipiac': 1, '...
# 95     {'1995castle': 1, 'angilley': 1, 'unitedplymou...
# 99     {'vfagrieg': 1, 'carltona': 1, 'handballin': 1...
# 101    {'yards1992': 1, 'eaglesstewart': 1, 'overall1...
# 102    {'pickjacobson': 1, 'fivefoot': 1, 'playoffjac...
# 105    {'indycarf1nascarin': 1, 'penskethe': 1, 'moto...
# 114    {'gameby': 1, 'starhairston': 1, 'kentmeridian...
# 116    {'usacs': 1, 'shuman': 7, 'fairgrounds': 1, '2...
# 118    {'vflyoung': 1, 'soyoung': 1, 'gippslandin': 1...
# 122    {'hailpin': 1, 'piarsaigh': 2, 'alln': 1, 'hai...
# 123    {'mccalliog': 1, 'gunnislake': 1, 'wednesdayde...
# 137    {'asbk': 1, 'epsa': 1, 'falzon': 1, 'yzfr6': 1...
# 145    {'100200and': 1, 'prenzler': 1, 'mcmasterhe': ...
# 151    {'2014fila': 1, 'ovalat': 1, 'whistleoriginall...
# 152    {'afljames': 1, 'deteriorating': 1, 'cartilage...
# 153    {'paristhey': 1, 'jerzeau': 1, 'emeris': 2, 'm...
# ...                                                  ...
# 58932  {'seasonclark': 1, 'walkons': 1, 'incidentafte...
# 58933  {'1994justin': 1, '112107': 1, 'assns': 1, 'ni...
# 58940  {'microfracture': 1, 'holmgren': 1, 'labrum': ...
# 58941  {'receiverthrough': 1, 'teamstwo': 1, '6586': ...
# 58943  {'minutesa': 1, '15hr': 1, 'bibbulmun': 1, '23...
# 58944  {'marussell': 1, 'meetwhile': 1, '11155': 1, '...
# 58949  {'castlefordmarc': 1, 'fages': 1, 'campaignfor...
# 58950  {'visitupon': 1, 'arigo': 1, 'phis': 1, 'barak...
# 58954  {'37his': 1, 'foytack': 2, 'kostro': 1, '8687'...
# 58960  {'alashkert': 2, 'navoyan': 1, 'erzrumyan': 4,...
# 58962  {'careerallan': 1, 'australialeslie': 1, 'acqu...
# 58968  {'abg': 1, 'deanluby': 1, 'is200': 1, 'bellm':...
# 58969  {'maxvill': 1, 'kgdaviault': 1, 'daviault': 4,...
# 58982  {'forkball': 1, 'majorsgray': 1, 'obradys': 1,...
# 58985  {'crosswelldavis': 1, 'platelets': 1, 'yearsfo...
# 58987  {'metsafter': 1, '3851': 1, 'hitsfor': 1, 'bru...
# 58988  {'swaggerhager': 1, 'swagger': 1, 'fcw': 2, 'h...
# 58992  {'collegeeddys': 1, 'hudspeths': 1, 'eddys': 2...
# 58993  {'rentera': 3, 'renteia': 1, 'redsborn': 1, 'h...
# 59003  {'149120': 1, '8470': 1, 'dunkenbergerher': 1,...
# 59007  {'dessings': 1, 'dessing': 1, 'durhamduring': ...
# 59010  {'valehe': 1, 'cwmbrn': 1, 'kaid': 1, 'yusef':...
# 59018  {'statesoriginally': 1, 'hadcapable': 1, 'reen...
# 59026  {'townthompson': 1, 'crisisnewport': 1, 'torqu...
# 59028  {'naposki': 5, 'jetson': 1, 'nanette': 2, 'mcl...
# 59051  {'5931': 1, '5926': 1, '131223': 1, '20912': 1...
# 59052  {'averagenilsson': 1, 'academynilsson': 1, 'we...
# 59065  {'2k': 2, 'decovan': 1, '2k12on': 1, 'nolook':...
# 59068  {'3257': 1, '15696': 1, 'grewcock': 1, 'orient...
# 59069  {'recordselias': 1, 'cochampionship': 1, 'xfl'...
#
# [11510 rows x 4 columns], 'centroid': array([  0.00000000e+00,   8.57526623e-06,   0.00000000e+00, ...,
#          1.38560691e-04,   6.46049863e-05,   2.26551103e-05])}
# {'matrix': <47561x547979 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8493452 stored elements in Compressed Sparse Row format>, 'dataframe':                                                      URI  \
# 1           <http://dbpedia.org/resource/Alfred_J._Lewy>
# 2            <http://dbpedia.org/resource/Harpdog_Brown>
# 3      <http://dbpedia.org/resource/Franz_Rottensteiner>
# 4                   <http://dbpedia.org/resource/G-Enka>
# 5            <http://dbpedia.org/resource/Sam_Henderson>
# 6            <http://dbpedia.org/resource/Aaron_LaCrate>
# 7          <http://dbpedia.org/resource/Trevor_Ferguson>
# 8             <http://dbpedia.org/resource/Grant_Nelson>
# 9             <http://dbpedia.org/resource/Cathy_Caruth>
# 10            <http://dbpedia.org/resource/Sophie_Crumb>
# 11           <http://dbpedia.org/resource/Jenn_Ashworth>
# 12        <http://dbpedia.org/resource/Jonathan_Hoefler>
# 13     <http://dbpedia.org/resource/Anthony_Gueterboc...
# 14      <http://dbpedia.org/resource/David_Chernushenko>
# 15          <http://dbpedia.org/resource/Joerg_Steineck>
# 16          <http://dbpedia.org/resource/Andrew_Pinsent>
# 18       <http://dbpedia.org/resource/Alexandros_Mouzas>
# 19     <http://dbpedia.org/resource/John_Angus_Campbell>
# 20          <http://dbpedia.org/resource/Chris_Batstone>
# 23           <http://dbpedia.org/resource/Faith_Soloway>
# 24            <http://dbpedia.org/resource/Tom_Jennings>
# 26         <http://dbpedia.org/resource/Anthony_Caruana>
# 27     <http://dbpedia.org/resource/Ian_Mitchell_(aut...
# 29            <http://dbpedia.org/resource/Emily_Osment>
# 31     <http://dbpedia.org/resource/Ted_Hill_(mathema...
# 32         <http://dbpedia.org/resource/Mindaugas_Murza>
# 34          <http://dbpedia.org/resource/Douglas_Davies>
# 35     <http://dbpedia.org/resource/Freimut_B%C3%B6rn...
# 36     <http://dbpedia.org/resource/Th%C3%BCring_Br%C...
# 37         <http://dbpedia.org/resource/Aharon_Solomons>
# ...                                                  ...
# 59036        <http://dbpedia.org/resource/Sabitri_Mitra>
# 59037     <http://dbpedia.org/resource/Roni_Lynn_Deutch>
# 59038           <http://dbpedia.org/resource/Simon_Vega>
# 59039          <http://dbpedia.org/resource/Cho_Oh-hyun>
# 59040  <http://dbpedia.org/resource/Gail_Kulick_Jackson>
# 59041          <http://dbpedia.org/resource/Mokob%C3%A9>
# 59042      <http://dbpedia.org/resource/F._Enzio_Busche>
# 59043      <http://dbpedia.org/resource/Christian_Wiman>
# 59044  <http://dbpedia.org/resource/Ellyn_Setnor_Bogd...
# 59045          <http://dbpedia.org/resource/Katya_Adler>
# 59046   <http://dbpedia.org/resource/Anthony-Noel_Kelly>
# 59047       <http://dbpedia.org/resource/Mignon_Clyburn>
# 59048    <http://dbpedia.org/resource/Charles_A._Miller>
# 59049       <http://dbpedia.org/resource/Rodolfo_Parada>
# 59050  <http://dbpedia.org/resource/Giwi_Margwelaschw...
# 59053       <http://dbpedia.org/resource/Jessica_Jordan>
# 59054     <http://dbpedia.org/resource/Marina_Mulyayeva>
# 59055  <http://dbpedia.org/resource/Jo%C3%ABl_de_Rosnay>
# 59056          <http://dbpedia.org/resource/Amy_Jenkins>
# 59057  <http://dbpedia.org/resource/Roy_Zimmerman_(sa...
# 59058        <http://dbpedia.org/resource/George_Krause>
# 59059           <http://dbpedia.org/resource/Sean_Slade>
# 59060         <http://dbpedia.org/resource/Lynne_Lipton>
# 59061             <http://dbpedia.org/resource/Rod_Wilt>
# 59062  <http://dbpedia.org/resource/Scott_Baker_(judge)>
# 59063  <http://dbpedia.org/resource/Dragoljub_Ojdani%...
# 59064            <http://dbpedia.org/resource/Oz_Bengur>
# 59066           <http://dbpedia.org/resource/Olari_Elts>
# 59067       <http://dbpedia.org/resource/Scott_F._Crago>
# 59070         <http://dbpedia.org/resource/Fawaz_Damrah>
#
#                                           name  \
# 1                               Alfred J. Lewy
# 2                                Harpdog Brown
# 3                          Franz Rottensteiner
# 4                                       G-Enka
# 5                                Sam Henderson
# 6                                Aaron LaCrate
# 7                              Trevor Ferguson
# 8                                 Grant Nelson
# 9                                 Cathy Caruth
# 10                                Sophie Crumb
# 11                               Jenn Ashworth
# 12                            Jonathan Hoefler
# 13     Anthony Gueterbock, 18th Baron Berkeley
# 14                          David Chernushenko
# 15                              Joerg Steineck
# 16                              Andrew Pinsent
# 18                           Alexandros Mouzas
# 19                         John Angus Campbell
# 20                              Chris Batstone
# 23                               Faith Soloway
# 24                                Tom Jennings
# 26                             Anthony Caruana
# 27                       Ian Mitchell (author)
# 29                                Emily Osment
# 31                    Ted Hill (mathematician)
# 32                             Mindaugas Murza
# 34                              Douglas Davies
# 35                        Freimut B%C3%B6rngen
# 36                      Th%C3%BCring Br%C3%A4m
# 37                             Aharon Solomons
# ...                                        ...
# 59036                            Sabitri Mitra
# 59037                         Roni Lynn Deutch
# 59038                               Simon Vega
# 59039                              Cho Oh-hyun
# 59040                      Gail Kulick Jackson
# 59041                              Mokob%C3%A9
# 59042                          F. Enzio Busche
# 59043                          Christian Wiman
# 59044                   Ellyn Setnor Bogdanoff
# 59045                              Katya Adler
# 59046                       Anthony-Noel Kelly
# 59047                           Mignon Clyburn
# 59048                        Charles A. Miller
# 59049                           Rodolfo Parada
# 59050                     Giwi Margwelaschwili
# 59053                           Jessica Jordan
# 59054                         Marina Mulyayeva
# 59055                      Jo%C3%ABl de Rosnay
# 59056                              Amy Jenkins
# 59057                 Roy Zimmerman (satirist)
# 59058                            George Krause
# 59059                               Sean Slade
# 59060                             Lynne Lipton
# 59061                                 Rod Wilt
# 59062                      Scott Baker (judge)
# 59063                   Dragoljub Ojdani%C4%87
# 59064                                Oz Bengur
# 59066                               Olari Elts
# 59067                           Scott F. Crago
# 59070                             Fawaz Damrah
#
#                                                     text  \
# 1      alfred j lewy aka sandy lewy graduated from un...
# 2      harpdog brown is a singer and harmonica player...
# 3      franz rottensteiner born in waidmannsfeld lowe...
# 4      henry krvits born 30 december 1974 in tallinn ...
# 5      sam henderson born october 18 1969 is an ameri...
# 6      aaron lacrate is an american music producer re...
# 7      trevor ferguson aka john farrow born 11 novemb...
# 8      grant nelson born 27 april 1971 in london also...
# 9      cathy caruth born 1955 is frank h t rhodes pro...
# 10     sophia violet sophie crumb born september 27 1...
# 11     jenn ashworth is an english writer she was bor...
# 12     jonathan hoefler born august 22 1970 is an ame...
# 13     anthony fitzhardinge gueterbock 18th baron ber...
# 14     david chernushenko born june 1963 in calgary a...
# 15     joerg steineck is a german filmmaker editor an...
# 16     fr andrew pinsent born 19 august 1966 is resea...
# 18     alexandros mouzas born 1962 is a greek compose...
# 19     john angus campbell born march 10 1942 in port...
# 20     chris batstone was the 20002002 lead singer of...
# 23     faith soloway born march 28 1964 is an america...
# 24     tom jennings born 1955 as thomas daniel jennin...
# 26     anthony caruana born 2 january 1968 is a melbo...
# 27     ian mitchell is a scottish author who grew up ...
# 29     emily jordan osment born march 10 1992 is an a...
# 31     theodore preston hill born december 28 1943 is...
# 32     mindaugas gervaldas until 2012 year mindaugas ...
# 34     douglas james davies born 1947 is professor in...
# 35     freimut brngen born october 17 1930 is a germa...
# 36     thring brm born 10 april 1944 is a swiss compo...
# 37     aharon solomons b september 27 1939 is a freed...
# ...                                                  ...
# 59036  sabitri mitra is an indian politician belongin...
# 59037  roni lynn deutch is a former tax attorney and ...
# 59038  simon h vega born october 8 1935 is a retired ...
# 59039  seorak musan cho oh hyun born in 1932 in mirya...
# 59040  gail kulick jackson born may 29 1959 is a minn...
# 59041  mokob traor better known by the mononym mokob ...
# 59042  friedrich enzio busche born 5 april 1930 dortm...
# 59043  christian wiman is an american poet and editor...
# 59044  ellyn setnor bogdanoff born october 17 1959 wa...
# 59045  katya adler born 1972 is a british journalist ...
# 59046  anthonynoel kelly born 1956 is a british artis...
# 59047  mignon l clyburn born march 22 1962 is a commi...
# 59048  charles a miller born october 27 1937 in washi...
# 59049  rodolfo parada lillo is a chilean musician com...
# 59050  giwi margwelaschwili georgian born december 14...
# 59053  jessica anne jordan burton born 6 may 1984 in ...
# 59054  marina vladimirovna mulyayeva kazakh born apri...
# 59055  jol de rosnay born 1937 phd from the massachus...
# 59056  amy jenkins born 1966 in london is an english ...
# 59057  roy zimmerman born october 7 1957 is an americ...
# 59058  george krause born 1937 philadelphia pennsylva...
# 59059  sean slade b november 14 1957 lansing michigan...
# 59060  lynne lipton is an american film stage televis...
# 59061  rod wilt is a former republican member of the ...
# 59062  sir thomas scott gillespie baker born 10 decem...
# 59063  dragoljub ojdani serbian cyrillic born june 1 ...
# 59064  osman oz bengur born february 23 1949 is an am...
# 59066  olari elts born april 27 1971 in tallinn eston...
# 59067  scott francis crago born july 26 1963 twin bro...
# 59070  fawaz mohammed damrah arabic fawwz damra was t...
#
#                                               word_count
# 1      {'maladaptation': 1, 'phasedelay': 1, '25hour'...
# 2      {'germanyover': 1, 'bluesgospel': 1, 'harpdog'...
# 3      {'fantasticrottensteiner': 1, 'waidmannsfeld':...
# 4      {'arhm': 3, 'gangstergenka': 1, 'kuhnja': 1, '...
# 5      {'historyhenderson': 1, 'onteora': 1, '1991hen...
# 6      {'pellatfinet': 1, 'lacrates': 1, 'baltimoreaa...
# 7      {'2014city': 1, 'kinkajou': 1, 'bunkhousesin':...
# 8      {'garagehe': 1, 'hardcores': 1, 'wishdokta': 3...
# 9      {'caruths': 1, 'deborash': 1, '173182': 1, 'ca...
# 10     {'americanfrench': 1, 'kominskycrumbcrumb': 1,...
# 11     {'quillercouch': 1, 'universityashworths': 1, ...
# 12     {'splithoefler': 1, 'morninghoeflers': 1, 'hef...
# 13     {'8595gueterbock': 1, 'fitzhardinge': 1, 'corn...
# 14     {'bodieschernushenko': 1, '2013chernushenko': ...
# 15     {'84minute': 1, 'steineck': 4, 'truckfighters'...
# 16     {'collaborationfr': 1, 'secondperson': 2, 'mar...
# 18     {'unionnaxos': 1, 'airesis': 1, 'kamarotos': 1...
# 19     {'landram': 1, 'schoolboard': 1, 'affairscampb...
# 20     {'remixchris': 1, 'albumchris': 1, 'tint': 1, ...
# 23     {'hamletta': 1, 'bobbies': 1, 'harlyn': 1, 'so...
# 24     {'stehlik': 1, 'fidonet': 2, 'europejennings':...
# 26     {'searchcio': 1, 'techtarget': 1, '330pmsince'...
# 27     {'apparentlyvirtuous': 1, 'bureaucracymitchell...
# 29     {'gerti': 1, 'diamondosment': 1, 'dadnapped': ...
# 31     {'benfords': 1, 'natonsf': 1, 'divisionborn': ...
# 32     {'logikos': 1, 'rapova': 1, 'gervaldas': 3, 's...
# 34     {'christianityprofessor': 1, '2003within': 1, ...
# 35     {'ahnert': 1, 'freimuthhe': 1, 'freimut': 1, '...
# 36     {'suissebrm': 1, 'schatt': 1, 'conductorbrm': ...
# 37     {'greatwood': 1, 'pipin': 1, 'freedivingsolomo...
# ...                                                  ...
# 59036  {'bengalsabitri': 1, '64641': 1, '38member': 1...
# 59037  {'collectibledeutch': 1, 'simz': 1, 'rdtc': 1,...
# 59038  {'mississippivega': 1, 'tennesseevega': 1, 'si...
# 59039  {'josil': 2, 'musan': 9, 'seon': 7, 'chiyong':...
# 59040  {'attorneyjackson': 1, 'divisionjackson': 1, '...
# 59041  {'molare': 1, '2011mokob': 1, 'tayorault': 1, ...
# 59042  {'busche': 4, 'enzio': 1, 'churchbusches': 1, ...
# 59043  {'wimans': 2, 'lineturnovers': 1, 'wiman': 2, ...
# 59044  {'marginwhen': 1, 'bogdanoff': 9, 'jenne': 1, ...
# 59045  {'bombingsfrom': 1, 'hewittadler': 1, '1998adl...
# 59046  {'faggionato': 1, 'researchbetween': 1, 'parts...
# 59047  {'unsatisfactorily': 1, 'critiziced': 1, 'comm...
# 59048  {'frabjous': 1, '197498': 1, 'trackaday': 4, '...
# 59049  {'complainte': 1, 'ausente': 1, 'susurro': 1, ...
# 59050  {'wakusch': 1, 'giwi': 4, 'berlinweissensee': ...
# 59053  {'macroregions': 1, 'ademaf': 1, 'huacaraje': ...
# 59054  {'22409at': 1, 'marylandmulyayeva': 1, '22425m...
# 59055  {'industriesde': 1, 'pronetaire': 1, 'gladwyn'...
# 59056  {'bicks': 1, 'heawood': 1, 'twonovel': 1, 'toy...
# 59057  {'foremen': 1, 'showzimmerman': 1, 'yup': 4, '...
# 59058  {'wondergeorge': 1, 'unmovedbe': 1, 'krauses':...
# 59059  {'singlesslade': 1, 'kolderie': 4, 'boekbinder...
# 59060  {'sanfran': 1, 'guilfordshe': 1, 'lunatacs': 1...
# 59061  {'1990wilt': 1, 'pennsylvaniawilt': 1, 'thiel'...
# 59062  {'guardianbaker': 1, 'negligencehe': 1, 'court...
# 59063  {'ictyin': 1, 'ojdanics': 2, 'korpus': 1, 'rav...
# 59064  {'eggspectation': 1, 'bengur': 9, 'franchiser'...
# 59066  {'orchestraolaris': 1, 'ivth': 1, 'nyyd': 1, '...
# 59067  {'procushion': 1, '5088376': 1, 'trafton': 3, ...
# 59070  {'damra': 1, 'damrah': 4, 'fawwz': 1, 'trustee...
#
# [47561 rows x 4 columns], 'centroid': array([  3.00882137e-06,   0.00000000e+00,   2.88868244e-06, ...,
#          1.10291526e-04,   9.00609890e-05,   2.03703564e-05])}

# %%
map_index_to_word_inv = {v: k for k, v in map_index_to_word.items()}

# %%
def display_single_tf_idf_cluster(cluster, map_index_to_word):
    '''map_index_to_word: SFrame specifying the mapping betweeen words and column indices'''
    
    wiki_subset   = cluster['dataframe']
    tf_idf_subset = cluster['matrix']
    centroid      = cluster['centroid']
    
    ## Print top 5 words with largest TF-IDF weights in the cluster
    idx = centroid.argsort()[::-1]
    for i in range(5):
        print('{0:s}:{1:.3f}'.format(map_index_to_word_inv[idx[i]], centroid[idx[i]])),
    print('')
    
    # Compute distances from the centroid to all data points in the cluster.
    distances = pairwise_distances(tf_idf_subset, [centroid], metric='euclidean').flatten()
    # compute nearest neighbors of the centroid within the cluster.
    nearest_neighbors = distances.argsort()
    # For 8 nearest neighbors, print the title as well as first 180 characters of text.
    # Wrap the text at 80-character mark.
    for i in range(8):
        print(nearest_neighbors[i])
        text = ' '.join(wiki_subset[wiki_subset.index==nearest_neighbors[i]]['text'].values[0].split(None, 25)[0:25])
        print('* {0:50s} {1:.5f}\n  {2:s}\n  {3:s}'.format(wiki_subset[nearest_neighbors[i]]['name'],
              distances[nearest_neighbors[i]], text[:90], text[90:180] if len(text) > 90 else ''))
    print('')

# %%
display_single_tf_idf_cluster(left_child, map_index_to_word)
display_single_tf_idf_cluster(right_child, map_index_to_word)
# Out:
# league:0.040
# season:0.036
# team:0.029
# football:0.029
# played:0.028
#
# 6830
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-96-8479d8891e52> in <module>()
# ----> 1 display_single_tf_idf_cluster(left_child, map_index_to_word)
#       2 display_single_tf_idf_cluster(right_child, map_index_to_word)
#
# <ipython-input-95-34ab6deaf2f7> in display_single_tf_idf_cluster(cluster, map_index_to_word)
#      20     for i in range(8):
#      21         print(nearest_neighbors[i])
# ---> 22         text = ' '.join(wiki_subset[wiki_subset.index==nearest_neighbors[i]]['text'].values[0].split(None, 25)[0:25])
#      23         print('* {0:50s} {1:.5f}\n  {2:s}\n  {3:s}'.format(wiki_subset[nearest_neighbors[i]]['name'],
#      24               distances[nearest_neighbors[i]], text[:90], text[90:180] if len(text) > 90 else ''))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
athletes = left_child
non_athletes = right_child

# %%
# Bipartition the cluster of athletes
left_child_athletes, right_child_athletes = bipartition(athletes, maxiter=100, num_runs=6, seed=1)

# %%
display_single_tf_idf_cluster(left_child_athletes, map_index_to_word)

# %%
display_single_tf_idf_cluster(right_child_athletes, map_index_to_word)

# %%
athletes = left_child
non_athletes = right_child

# %%
# Bipartition the cluster of athletes
left_child_athletes, right_child_athletes = bipartition(athletes, maxiter=100, num_runs=6, seed=1)

# %%
baseball            = left_child_athletes
ice_hockey_football = right_child_athletes

# %%
left_child_ihs, right_child_ihs = bipartition(ice_hockey_football, maxiter=100, num_runs=6, seed=1)

# %%
map_index_to_word
# Out:
# {'biennials': 522004,
#  'lb915': 116290,
#  'shatzky': 127647,
#  'woode': 174106,
#  'damfunk': 133206,
#  'nualart': 153444,
#  'hatefillot': 164111,
#  'missionborn': 261765,
#  'yeardescribed': 161075,
#  'theoryhe': 521685,
#  'vinalop': 222759,
#  'soestdijk': 166345,
#  'boncea': 150371,
#  'spiders': 519990,
#  'bienniale': 429277,
#  'woody': 541515,
#  'trawling': 189895,
#  'pampoulovawagner': 201040,
#  'bentara': 202586,
#  'laserbased': 25758,
#  'caner': 346073,
#  'canes': 478262,
#  'canet': 436468,
#  'iaspark': 395341,
#  'categoriesborn': 12586,
#  '5982': 277649,
#  'caney': 459867,
#  'phosphorushe': 379479,
#  'yusaf': 270311,
#  'hhsoffice': 141697,
#  '5985': 32985,
#  'fsos': 109474,
#  'caned': 324502,
#  'gaa': 534680,
#  'iguau': 456103,
#  'storiesin': 513151,
#  'braziljorge': 107111,
#  'iguaz': 127410,
#  'kealhofer': 342134,
#  'canek': 159182,
#  '2116': 429919,
#  'canem': 83461,
#  'victorialooking': 58169,
#  'martre': 111954,
#  'lippert': 491344,
#  'pagesolove': 33220,
#  'sowell': 489254,
#  'weiskopfs': 344360,
#  'hedquist': 165506,
#  'andersanders': 395286,
#  'raouf': 429695,
#  'steppaillen': 107270,
#  'fjate': 223085,
#  'heroesin': 467576,
#  'executivemanager': 66489,
#  'papanastassiouwasserburgs': 159142,
#  'superpowered': 459105,
#  'voiceactress': 171818,
#  'fullblooded': 481011,
#  'genocidekamuhanda': 153083,
#  'radkes': 273097,
#  'composertippett': 435288,
#  'grueling': 521723,
#  'season1bouyer': 303715,
#  'wooden': 539936,
#  'comicborn': 98129,
#  'virtuosos': 502172,
#  'raoul': 533170,
#  'illinoisrockefellersilvia': 125605,
#  'nielsenfunk': 139592,
#  'woodes': 31701,
#  '598m': 118443,
#  'semiautomatic': 514410,
#  'immunities': 453709,
#  'racedue': 43704,
#  'jher': 414423,
#  'oropolitics': 369894,
#  'thrace': 26128,
#  'voiceguitar': 3162,
#  'jhey': 103639,
#  'snuggles': 4139,
#  'brockiehe': 149987,
#  'frederick': 543425,
#  'pinerichland': 292867,
#  'deadheads': 121406,
#  'troycale': 351786,
#  'kqrsminneapolis': 152278,
#  'vlez': 517536,
#  'collegerozanskis': 192387,
#  'consenting': 479773,
#  'finalsst': 11048,
#  'bastenesque': 310891,
#  'irelandroche': 217427,
#  'career1996': 215694,
#  'leopardis': 155769,
#  '2013previously': 460148,
#  'antisandinista': 184027,
#  'outfieldera': 144388,
#  'comically': 513628,
#  '2005marino': 349655,
#  'yanhai': 141251,
#  'termbarro': 274617,
#  'outfielders': 526971,
#  'replaced': 546924,
#  'isbin': 459302,
#  'paparizu': 44185,
#  'reber': 456999,
#  'rocqui': 207708,
#  'alwan': 491122,
#  'bhubaneshwar': 399845,
#  'syndromehe': 460242,
#  'dogscott': 155848,
#  'slubena': 385730,
#  'iraq20042005': 178147,
#  'ninefight': 42708,
#  'softwareas': 354920,
#  'canadaday': 51281,
#  'instituteoue': 198370,
#  'ulpio': 54184,
#  'whbqam': 118422,
#  'shvegerins': 213251,
#  '2008hilary': 122189,
#  'jlana': 124099,
#  'votesprior': 459253,
#  'geoghegans': 438741,
#  'gaspatilla': 324178,
#  'deferring': 124557,
#  'gayathri': 298893,
#  'reidun': 452986,
#  'soundsdrew': 423,
#  'crowdpleasing': 292122,
#  '2003radloff': 320227,
#  'tokmok': 287716,
#  'vr51': 372568,
#  'talba': 179396,
#  'raavan': 464594,
#  'gastein': 134708,
#  'nok10': 204313,
#  'adultsas': 237067,
#  'buades': 36108,
#  'candmag': 507616,
#  'gasteig': 392086,
#  'legislaturebarraga': 311807,
#  'realbeanz': 179459,
#  'aviezer': 310902,
#  'lohren': 160168,
#  'frs': 539084,
#  'gasteiz': 303871,
#  'chanthaburi': 103456,
#  'gurinders': 182056,
#  'hiranuma': 371831,
#  'urbanbaby': 7246,
#  'modurn': 108979,
#  'elfvin': 210428,
#  'dnd': 399750,
#  'dng': 505359,
#  'dnf': 513629,
#  'dna': 542302,
#  'englandlifsons': 157092,
#  'dnc': 523024,
#  'dnb': 492771,
#  'dnl': 361850,
#  'dno': 415431,
#  'luchin': 11422,
#  'dni': 498236,
#  'dnk': 280927,
#  'inevitable': 529809,
#  'dnu': 16077,
#  'dnt': 150160,
#  'gothicmade': 153547,
#  'dnp': 464065,
#  '320506': 60694,
#  '124pm': 259004,
#  'kdziora': 220094,
#  'attenboroughin': 258997,
#  'attenboroughii': 389450,
#  'blasss': 190086,
#  'benedikt': 473505,
#  'linzbobby': 326871,
#  'sonhawick': 118345,
#  'ancastedundasflamboroughwestdale': 318333,
#  'borstal': 494481,
#  'populations': 538271,
#  'chapterinvited': 57924,
#  'borstad': 7914,
#  'gijs': 492503,
#  'gijn': 511449,
#  'rickman': 509770,
#  'ternuraincluding': 109605,
#  'milestones': 528741,
#  'expeditionary': 530154,
#  'securitylink': 70741,
#  'factiondue': 249593,
#  'oldwhite': 164293,
#  'ongirl': 379218,
#  'editornews': 34820,
#  'yearstandly': 374138,
#  '18o': 152283,
#  'wbzfm': 177754,
#  'uhlenbeek': 384379,
#  'planprescribercom': 211944,
#  'missionizing': 358226,
#  'dn5': 302164,
#  'cachaahe': 167832,
#  'godsandmonstersnet': 78576,
#  'chacottmckie': 92103,
#  'niven': 478423,
#  'ozment': 387785,
#  'dangdut': 418883,
#  'betdaq': 231888,
#  'journalsdruviete': 336649,
#  'tnnessons': 372688,
#  'legalva': 267175,
#  'irrationalist': 432385,
#  'usiuprior': 156395,
#  'mainevented': 432746,
#  'postbeginning': 60574,
#  'peopleher': 23167,
#  'langenbroich': 273971,
#  'goleas': 3474,
#  'sashays': 179094,
#  'dagriculture': 14323,
#  'breedens': 230886,
#  'insectarium': 393241,
#  'masekelain': 313160,
#  'castelo': 94551,
#  'azurite': 84044,
#  'basolo': 383335,
#  '200mile': 434259,
#  'norplast': 276091,
#  'latifaafter': 5136,
#  'olympiadhe': 87552,
#  'delmark': 483847,
#  'andreessenhorowitz': 234408,
#  'kraig': 440505,
#  'rosmonda': 437842,
#  'brandon': 541598,
#  'kfrc': 485824,
#  'shirked': 155003,
#  'fetters': 481077,
#  'thechancerie': 343871,
#  'tenalirama': 256962,
#  'krais': 324217,
#  '1974dyson': 36470,
#  'golddixon': 238869,
#  'ndvornk': 349158,
#  'menem': 519165,
#  'tohnay': 191692,
#  'venuesin': 498042,
#  'fieldsince': 390567,
#  'greylox': 271681,
#  'immigrantschneeberger': 309741,
#  'tevanyan': 19532,
#  'penhalonga': 17845,
#  'goober': 477968,
#  'balado': 391698,
#  'partymohamud': 374173,
#  'leavingafter': 98656,
#  'barbro': 463557,
#  'flossin': 342526,
#  'rolster': 311143,
#  '2002andre': 322961,
#  'leaguesnicknamed': 295418,
#  'morsesmale': 167928,
#  'dauvergne': 465435,
#  'ombattu': 259596,
#  'varyingly': 358419,
#  'worksdadyans': 84960,
#  'arkarazo': 124120,
#  'actingmann': 284127,
#  'dungkar': 20352,
#  'fazul': 386343,
#  'macken': 477363,
#  'chandos': 528336,
#  'shreya': 465102,
#  'injurymckeever': 66655,
#  'dikinis': 99674,
#  'marquett': 283498,
#  'ontaylor': 101785,
#  'sheenboro': 197283,
#  'chandon': 477855,
#  'analysisstill': 203812,
#  'sankarabharanam': 101690,
#  'disengaging': 335207,
#  'lafource': 199564,
#  'welcomed': 539363,
#  'malba': 425920,
#  'stoicism': 455423,
#  'ovalat': 24281,
#  'tillamook': 320600,
#  'tarbuckhodgson': 137902,
#  'telsys': 273308,
#  'seasoncurrie': 170537,
#  'bhatkal': 212029,
#  'claflin': 174070,
#  'ferrante': 503492,
#  'activating': 462046,
#  'telemetryshe': 83453,
#  'michelidakidarmouslis': 114175,
#  'welcomes': 497898,
#  'unimodality': 209880,
#  'entendstu': 209614,
#  'haripal': 364370,
#  'fiq': 216094,
#  'donemusin': 235759,
#  'fit': 542897,
#  'reviewingas': 48381,
#  'womenolson': 363469,
#  'fix': 535542,
#  'nationallyaccredited': 40567,
#  'folate': 415189,
#  'fic': 127131,
#  '204for815': 65998,
#  'postharvest': 394097,
#  'fif': 101309,
#  'fig': 515638,
#  'fid': 468759,
#  'fie': 478402,
#  'ergonomidesign': 71556,
#  'fih': 482219,
#  'fii': 134779,
#  'athleticcanvey': 285449,
#  'fio': 453059,
#  'fil': 537518,
#  'shively': 402001,
#  'mirandas': 469490,
#  'shivay': 161466,
#  'beilharz': 398501,
#  'foolin': 158507,
#  'cimms': 441713,
#  'packardin': 111548,
#  'sovs': 303334,
#  'vallibel': 359756,
#  '1984buffalo': 52999,
#  'hisin': 377426,
#  'mbarker': 373248,
#  'goresbrook': 110776,
#  'challengethe': 19032,
#  'ankor': 340561,
#  'ctamong': 68352,
#  'allergen': 393736,
#  'matamoras': 203483,
#  'hospitalier': 16297,
#  'conner': 532862,
#  'scaglione': 118922,
#  '26568': 85500,
#  'superdad': 379291,
#  'persita': 359286,
#  'musang': 280147,
#  'picturesfujimura': 127627,
#  'sugarplums': 344760,
#  'frewer': 300083,
#  'proffitts': 322661,
#  'grfenroda': 306879,
#  'musans': 268208,
#  'goverors': 13680,
#  'mancordycollins': 333985,
#  'lightningcloud': 360360,
#  'kowt': 230770,
#  'zuid': 464363,
#  '1395336': 249251,
#  'victoriangeorgianinspired': 336811,
#  'pavlina': 405971,
#  'environmentallyaware': 286532,
#  'titlefrom': 453772,
#  'parasiten': 283516,
#  'goldfishbraun': 345342,
#  'tenin': 487209,
#  'counterstreaming': 109742,
#  'holisticallyhistorical': 366008,
#  'niederst': 422575,
#  'buttercups': 183230,
#  'programmesmith': 252942,
#  'ideograph': 114893,
#  'exmanchester': 408299,
#  'malczewska': 347174,
#  'lapua': 425250,
#  'syd': 531185,
#  'dailyon': 114648,
#  'hivaidsawareness': 78876,
#  '2007jennings': 191868,
#  'economistherminio': 29848,
#  '7in': 504082,
#  'resolvedthis': 275819,
#  'cuchera': 244040,
#  'sportbikefor': 246916,
#  'mansonat': 122183,
#  'cinematographyin': 309326,
#  'pusks': 474954,
#  'abbots': 438904,
#  'worldbasem': 209262,
#  'hirschmore': 354975,
#  'julide': 305262,
#  'malich': 427967,
#  'ooooooone': 369795,
#  'pinakothek': 354639,
#  'bonelli': 460060,
#  'eventsakbar': 4528,
#  'pumpkins': 528279,
#  'springerkaufman': 111265,
#  'bonello': 448194,
#  '19731982in': 160307,
#  'bonella': 82461,
#  'nieuwpoort': 454564,
#  'berwick': 526842,
#  'abbotm': 246937,
#  'pakmed': 28471,
#  'sikiru': 18680,
#  'danuartadanuartas': 319007,
#  'serviceexternal': 66364,
#  '2015a': 447829,
#  'parkson': 187243,
#  'pisinski': 28517,
#  '28baron': 233604,
#  'tourcoetzee': 111546,
#  'stranka': 422748,
#  'msu': 522640,
#  'vilarinhos': 326440,
#  'albumrolinha': 372678,
#  'kiersey': 46609,
#  'jkhis': 134574,
#  'krieble': 346681,
#  'shivajis': 89941,
#  'portmanteau': 507813,
#  'ineffectively': 444965,
#  'palani': 463350,
#  'alderson': 515665,
#  'competitionaaltonen': 77706,
#  'kneeduring': 381811,
#  'cofounderceo': 25755,
#  'whipsaltzman': 170263,
#  'curiouser': 221375,
#  'stoneham': 477185,
#  'skanderbeg': 231304,
#  'freimanescreen': 368646,
#  'liberecagusts': 128925,
#  'hushang': 47274,
#  'jeanphi': 352311,
#  'modernitys': 405970,
#  'tumes': 417354,
#  'analysiscurrently': 354767,
#  'niederers': 302297,
#  '2014mimis': 315738,
#  'ritterband': 236950,
#  'publishingms': 371346,
#  'sarodya': 128698,
#  'malick': 521020,
#  'aigles': 472231,
#  'cogeneral': 468768,
#  '13bn': 51149,
#  'couevas': 98663,
#  'habilitandenstipendiat': 360934,
#  'capsat': 406524,
#  'lewica': 445059,
#  'mercurys': 491067,
#  'swaralayam': 369721,
#  'systemsedwards': 381756,
#  'gmpls': 249466,
#  'shoutcasting': 323965,
#  'weighingroomriding': 334713,
#  'toomey': 491205,
#  'abdulwahab': 421143,
#  'izchak': 340747,
#  'casandra': 488608,
#  'bicskeis': 69880,
#  'huewen': 285078,
#  'frderpreis': 460028,
#  'onceinalifetime': 473412,
#  'songcycles': 456047,
#  '386840': 116559,
#  'yearsdrgillani': 296736,
#  'winterville': 411392,
#  'aztecadel': 185048,
#  'agurida': 122043,
#  'olthwaite': 137701,
#  'juaristi': 327900,
#  'tulsahis': 5499,
#  'talkinhe': 36361,
#  '272': 530207,
#  'nonastrological': 303009,
#  'ahmet': 527576,
#  'exclaimed': 498820,
#  '5606': 165413,
#  'mozartgemeinde': 22424,
#  'escopetarras': 117254,
#  'freelicks': 276235,
#  '274': 529544,
#  '2007lai': 319979,
#  'english2': 115277,
#  'provincecashin': 312614,
#  'hederson': 359424,
#  'wageswanson': 53952,
#  'sadki': 177396,
#  'germanymende': 316388,
#  'redesigned': 526793,
#  '15703': 235555,
#  'eslami': 459386,
#  '15706': 382839,
#  '1994tunisia': 337488,
#  'mandatrio': 266860,
#  'sciencesstaffan': 350595,
#  'carlands': 410407,
#  'lilinho': 64352,
#  'merseys': 365509,
#  'vectorborne': 448086,
#  'harassmenthis': 186529,
#  '24144': 113860,
#  'betteshanger': 305890,
#  'cotecnas': 138755,
#  'kraftlag': 403274,
#  'asnmsu': 177534,
#  'targa': 512651,
#  'instructionformer': 139085,
#  'trendsas': 282356,
#  'auctionsin': 272568,
#  'legislaturebeginning': 182087,
#  'welshofers': 252529,
#  'germanyk1997the': 266260,
#  'recordsoriginally': 374686,
#  'zidanegourcuff': 216949,
#  'netzbandt': 307490,
#  'footthe': 228790,
#  'jhen': 322933,
#  'kuhnian': 432997,
#  'terrorsleavitts': 75637,
#  'crocs': 482760,
#  'pixilated': 406476,
#  'karsavina': 108360,
#  'everscottas': 57582,
#  'democracyrecently': 22785,
#  'existentialistsin': 32553,
#  'eurobasketcom': 412149,
#  'descosidos': 209224,
#  'monger': 441664,
#  'functionary': 489924,
#  '1997bolen': 68773,
#  'modelsplatt': 137166,
#  'rocketplane': 387360,
#  '2012firth': 382267,
#  'maji': 306406,
#  'majk': 248523,
#  'majd': 317462,
#  'colloids': 472393,
#  'maja': 517442,
#  'azertion': 245409,
#  'nettle': 470313,
#  'insandamat': 301561,
#  'federley': 377241,
#  'demierre': 260780,
#  'awardkays': 126773,
#  'clichy': 482883,
#  'hiberian': 236623,
#  'costello': 536020,
#  'morawetz': 390996,
#  '2012daniels': 186114,
#  'tathamlaird': 147380,
#  'dickey': 525158,
#  'katsastus': 229468,
#  'rajapaksachampika': 289765,
#  'dicker': 472293,
#  'gillham': 246509,
#  'khalwale': 53238,
#  'mkhasmchog': 98728,
#  'gebrselassieworku': 73912,
#  'otello': 530252,
#  'hangama': 432368,
#  'redland': 485209,
#  'belgiumaprmay': 159585,
#  'chelios': 467322,
#  'conpany': 412067,
#  'apace': 402152,
#  'topfour': 462751,
#  'mikheil': 513118,
#  'economicallydriven': 212859,
#  'koloffchad': 204266,
#  'fellowpounds': 28053,
#  'lepidoptery': 140303,
#  '20052011was': 356166,
#  'apact': 125429,
#  'kaiapoi': 50813,
#  'attacksthroughout': 292251,
#  'arrogant': 524724,
#  'xlvii': 508619,
#  'bruneian': 466533,
#  'khvsgl': 12705,
#  'christiansbill': 184352,
#  '2005machage': 22862,
#  'damagede': 351582,
#  'bruneteaus': 6058,
#  '2014morris': 318716,
#  'neufbrisach': 175693,
#  'meeshelle': 78884,
#  'heartsounds': 97322,
#  'festivalfor': 428075,
#  'dumontier': 193672,
#  'satalyte': 173087,
#  'beginningdeva': 234376,
#  'theodosios': 24659,
#  'eurogp': 242552,
#  'panicsville': 141257,
#  'intorno': 445047,
#  'fruita': 440077,
#  'shakhovskayain': 267457,
#  'worldwideyaitanes': 267618,
#  'optimise': 396751,
#  'ennedi': 350087,
#  'nomenclaturedickinson': 369048,
#  'researchdescribed': 57022,
#  'scotlandfraser': 59602,
#  '2011s': 527026,
#  'alkudmani': 437419,
#  'veenlijken': 167576,
#  'effectsmusician': 121939,
#  'mxtv': 378539,
#  'amply': 451152,
#  'viehweg': 416215,
#  'aadam': 204323,
#  'primorac': 475690,
#  'muddled': 459408,
#  'nonmatchdays': 220022,
#  'programmatic': 513634,
#  'courneuve': 392914,
#  'manasseris': 262920,
#  'conanp': 200389,
#  'ludacristhe': 117251,
#  'garamendi': 463080,
#  'braconi': 141110,
#  'zahlen': 238511,
#  'staytongirod': 41534,
#  'mexicoin': 524820,
#  'tyndale': 516888,
#  'smpte': 492004,
#  'tyndall': 512807,
#  'proibidos': 226337,
#  'locallyderived': 354736,
#  'improvisatorysounding': 164487,
#  'doran': 524674,
#  'jorgovanka': 415,
#  '19771980': 526776,
#  'japankrentzman': 365948,
#  'ruusunen': 134926,
#  'schofieldhe': 247313,
#  'studiesgura': 215209,
#  'gizzyvan': 299811,
#  'gaventas': 151258,
#  'markpartnering': 241045,
#  'conductive': 468181,
#  'subarray': 267018,
#  'therekenneth': 322360,
#  'breakawayvasseur': 223947,
#  'shaider': 256046,
#  'spectrometers': 435047,
#  '19671dr': 383655,
#  'keyboardstony': 325146,
#  'sletten': 411782,
#  'gwozdz': 230221,
#  'seriously1': 39020,
#  '2002there': 284422,
#  'lapping': 400054,
#  'bealein': 81242,
#  'bpool': 87006,
#  'gced': 372510,
#  'meridional': 390078,
#  'learin': 408767,
#  'kazenga': 107002,
#  'cduk': 457884,
#  'copythe': 63436,
#  '29th': 540830,
#  'gcel': 248667,
#  'understandsfollowing': 69776,
#  'mailart': 238227,
#  '18921992': 203862,
#  'enochenochs': 191864,
#  'mexiconegrete': 65334,
#  'repremiered': 46951,
#  'khandap': 151246,
#  'sanguinetis': 110521,
#  'corvair': 46772,
#  'sucarnochee': 177119,
#  '2013fascinated': 23390,
#  'directorcohen': 134479,
#  'fundmcneilly': 198064,
#  'pitcheramaral': 6129,
#  '2011commander': 266951,
#  'officialhis': 68463,
#  'specialsit': 22198,
#  'coloursshe': 427126,
#  'fizzingly': 320772,
#  'bloggers': 534570,
#  'borrussia': 156058,
#  'meaningfulness': 45081,
#  'salvagedused': 299258,
#  'lankain': 91379,
#  'gretaborn': 207425,
#  'issuesblack': 130158,
#  'ahomage': 118958,
#  'praticado': 231099,
#  'eldoradowhile': 249869,
#  'bakalyans': 185281,
#  'washingtonlaughlin': 108479,
#  'gstaadkarl': 353797,
#  'otolaryngologists': 177582,
#  'escalada': 195228,
#  'castebased': 485678,
#  'chuanyun': 383788,
#  'growthessays': 269265,
#  'lanett': 423721,
#  'hardthrowers': 327753,
#  'cartright': 66358,
#  'imperfecta': 462705,
#  'gnima': 213078,
#  'finsbury': 485668,
#  'hegarty': 495078,
#  'nearupset': 286604,
#  'leduey': 335648,
#  'twangafter': 96800,
#  'berserky': 245712,
#  'giessen': 511845,
#  'takingchong': 307154,
#  '1679': 392644,
#  'picturejournalist': 234329,
#  'kidp': 274055,
#  'turda': 175792,
#  'mangual': 252173,
#  'artmahurin': 19982,
#  'miamiheadquartered': 318075,
#  'kgarm': 55571,
#  'nolanirish': 283376,
#  'koutsopoulos': 188232,
#  'arkiv': 355857,
#  'experienceboyces': 129466,
#  'state197579': 227692,
#  'kids': 545637,
#  'jarrin': 252685,
#  'aberchirder': 21014,
#  'developmentoriented': 18899,
#  'angee': 323580,
#  'propellants': 207925,
#  'uplifting': 524317,
#  'szetsung': 130410,
#  'teacherher': 222892,
#  '2004contrary': 351311,
#  'lafferentz': 44264,
#  'australiamark': 177589,
#  'mazher': 256697,
#  'sreten': 435027,
#  'herreros': 260628,
#  'thoughthis': 11490,
#  'alkhabyyr': 64944,
#  '1672': 2787,
#  'jointservice': 399562,
#  'pp6176': 229696,
#  'lithuaniahe': 57815,
#  'whatsherface': 22570,
#  'systemdaniel': 222968,
#  'aollynch': 78278,
#  'englandbelgium': 174458,
#  'unor': 93181,
#  'volapkspeakers': 331332,
#  'stanzaks': 362146,
#  'canoeing': 527324,
#  '254': 531510,
#  'tedxtokyo': 114667,
#  'walshby': 66352,
#  'anger': 538333,
#  'unob': 222989,
#  '1990playboy': 145665,
#  'hashilarosa': 248315,
#  'porvorimbbc': 126385,
#  'unog': 416100,
#  'recordsjack': 398023,
#  'branchhedgpeth': 298097,
#  'controversy': 546065,
#  'unol': 327774,
#  'kayama': 56269,
#  'roehrkasse': 397847,
#  'bricklayer': 509048,
#  'powsin': 191323,
#  'grinfield': 166932,
#  'planetable': 372397,
#  'remand': 511437,
#  'spews': 148186,
#  'producermalavasi': 102010,
#  'valdisre': 441889,
#  'statefrom': 461521,
#  'castlewellan': 294092,
#  'seasonpauls': 246434,
#  'baudry': 271575,
#  'campact': 4453,
#  'tasvir': 71716,
#  'georgics': 84840,
#  'teuschl': 190432,
#  'edelstammolin': 309844,
#  'sevenandahalf': 461689,
#  'staphylococci': 372830,
#  'georgica': 7027,
#  'zeor': 89872,
#  'altar': 527275,
#  'soundsation': 161371,
#  '75in': 197451,
#  'peremptory': 393706,
#  'menwan': 268290,
#  'futari': 387245,
#  'statesjen': 72493,
#  'stillness': 516400,
#  'mentorm': 319607,
#  'rajastanafter': 10507,
#  'veteran': 545906,
#  'aldhousegreens': 109743,
#  'toshizumi': 364310,
#  'yorklisted': 198299,
#  'absurdities': 461919,
#  '2010marlton': 155149,
#  'programinvited': 7568,
#  'karogshe': 153999,
#  'hechos': 409796,
#  'solesides': 154660,
#  'historicalfiction': 216151,
#  'hrfest': 234338,
#  'preparando': 235799,
#  'topography': 515769,
#  'valleys': 530848,
#  'monika': 526253,
#  'saatchi2007': 15615,
#  'kommunal': 409229,
#  'andryczuk': 342562,
#  'gainsbourg': 508291,
#  'vivalma': 202649,
#  'marignane': 306361,
#  'hastons': 339927,
#  'conferenceshe': 493801,
#  'pastchairman': 405494,
#  'radzinsky': 299298,
#  'bravewell': 162064,
#  'projectsengel': 186638,
#  'godlin': 357773,
#  '1958ehrenberg': 322841,
#  'stutzmann': 138193,
#  'bemsha': 259129,
#  'cristianes': 19489,
#  'godlia': 43799,
#  'cupriley': 252936,
#  'brays': 33599,
#  'identityhis': 114934,
#  'senecal': 64296,
#  'rescaled': 203490,
#  'dokka': 449636,
#  'yukawa': 196354,
#  'ascapjaqueline': 358055,
#  'redbrook': 95717,
#  'brebants': 167762,
#  'jerusalemgreenberg': 335245,
#  'gligori': 419258,
#  '47collingwood': 331791,
#  'championsthus': 5741,
#  'drummeras': 412772,
#  'indicative': 514223,
#  'dokku': 152698,
#  'clevedon': 519535,
#  'saucelilker': 383817,
#  'nonconsecutive': 520063,
#  'sleuthing': 452893,
#  'cambridgelord': 398550,
#  'bambos': 435283,
#  'victoria': 546580,
#  'scholasticas': 478305,
#  'languagenayler': 156392,
#  'kremlins': 454565,
#  '2002gerlachs': 186498,
#  'francedeveloped': 225697,
#  'furtsch': 120528,
#  'potterof': 257552,
#  'anklehinton': 212758,
#  'lakembafurolo': 337060,
#  'daniellespiva': 96601,
#  '2004gronkiewiczwaltz': 156344,
#  'mccumbee': 200097,
#  'svechi': 393117,
#  'unsinkable': 470150,
#  'rusherfollowing': 359398,
#  'yavana': 383534,
#  'staff2013': 172757,
#  '2014ole': 136066,
#  'argylein': 433937,
#  'dailyhe': 403778,
#  'ecoterrorismhardwick': 183086,
#  'visitin': 416140,
#  'pileggi': 48054,
#  'sneha': 456161,
#  'hoysince': 136989,
#  'gambale': 488575,
#  'onemake': 496328,
#  'naurai': 303675,
#  'ratatattat': 19625,
#  'fruh': 31321,
#  'oneschulmans': 195445,
#  'fruc': 225390,
#  'gamblingaddicted': 132854,
#  'layeredsound': 277595,
#  'youtubeshahrzad': 167261,
#  'fehman': 279418,
#  'dne': 214844,
#  'iheanacho': 192828,
#  'itsuwa': 371689,
#  'giannabest': 24938,
#  'httpwwwhavchrengcroatianfilmcroatianfilmcataloguenosleepwontkillyou': 156463,
#  'agassi': 517708,
#  'schrder': 517781,
#  'taifai': 406291,
#  'spectatorhe': 240082,
#  'herrin': 488502,
#  'evacuees': 452390,
#  '1961wirsum': 218786,
#  'holofernes': 163500,
#  'hammersberg': 41108,
#  'vrilissia': 327102,
#  'qaralov': 106072,
#  'herria': 392151,
#  'fiveway': 493441,
#  'myfontscommarshs': 107219,
#  'fingleson': 406684,
#  'spaceships': 478562,
#  'svipdagr': 102809,
#  '2011books': 163539,
#  'altai': 444944,
#  'imtogether': 243941,
#  'biocharacterization': 258947,
#  'everestjbf': 225369,
#  'categoryluckey': 381595,
#  'wankelengined': 265777,
#  'parliamentfor': 450595,
#  'vonage': 221910,
#  'eisnehower': 17908,
#  'honeymood': 122135,
#  'hurdlesand': 364213,
#  'associationaside': 332116,
#  'functiongrier': 358766,
#  'macedoniahis': 138786,
#  'knockdownin': 378855,
#  'marshall': 544997,
#  'honeymoon': 527844,
#  'lebedlebedbizstafflebed': 187367,
#  'semifinalon': 393152,
#  'duccia': 428436,
#  'oppressionhe': 144773,
#  'cruisewagner': 422290,
#  'marshals': 525554,
#  'penaltiesdixie': 129988,
#  'haboush': 282330,
#  'university3': 340779,
#  'university2': 398401,
#  'university1': 497585,
#  'university6': 70917,
#  'university5': 192796,
#  'fluegelman': 217371,
#  'abdulhamid': 58421,
#  'biddulph': 454458,
#  'littenstall': 108375,
#  'islamin': 493567,
#  'timewitt': 335540,
#  'courtprofessor': 20641,
#  'chairmanadubato': 55125,
#  'dnv': 444313,
#  'digitalvibe': 110375,
#  'historianshuntsman': 49679,
#  'allsoutheastern': 511044,
#  'alexandrian': 443364,
#  'belfaston': 281004,
#  'secretarykeith': 94479,
#  'dns': 506262,
#  'altan': 457766,
#  'awardswoodard': 374357,
#  'universityb': 315716,
#  'universitya': 527175,
#  'masterkris': 275982,
#  'tobagomaraj': 313450,
#  'thesaurus': 487872,
#  'alistairs': 3994,
#  'germanirish': 448014,
#  'olowo': 31779,
#  'kaizers': 460749,
#  'moraima': 307640,
#  'universitys': 546532,
#  'vietnamese': 539756,
#  'endocytic': 209899,
#  'mgab': 207712,
#  'huoche': 369302,
#  'dny': 465205,
#  'layin': 140064,
#  'leaguegul': 11924,
#  'agrifood': 506525,
#  'aphasia': 490245,
#  '2231': 207291,
#  'fheasgair': 199122,
#  'mzilikazi': 395283,
#  'lesea': 363629,
#  '2233': 120379,
#  'gelbers': 352136,
#  'allbaughs': 114959,
#  'sondelli': 346013,
#  ...}
